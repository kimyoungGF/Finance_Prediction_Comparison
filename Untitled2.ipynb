# %%
import pandas as pd
import numpy as np
import FinanceDataReader as fdr
import matplotlib.pyplot as plt

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, Bidirectional

from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

import xgboost as xgb

# %%
def MinMaxScaler(data):
    numerator = data - np.min(data, 0)
    denominator = np.max(data, 0) - np.min(data, 0)
    return numerator / (denominator + 1e-7)

# %%
def BLSTM(finnum):    
    df = fdr.DataReader(f'{finnum}', '2018-01-01', '2023-01-01')
    dfx = df[['Open','High','Low','Volume', 'Close']]
    dfx = MinMaxScaler(dfx)
    dfy = dfx[['Close']]
    dfx = dfx[['Open','High','Low','Volume']]
    dfx=dfx.reset_index()
    dfx=dfx.set_index(keys='Date')


    X = dfx.values.tolist()
    y = dfy.values.tolist()

    #며칠데이터로 예측
    window_size = 10

    data_X = []
    data_y = []
    for i in range(len(y) - window_size):
        _X = X[i : i + window_size] 
        _y = y[i + window_size]     
        data_X.append(_X)
        data_y.append(_y)


    n=len(data_y)

    train_X = np.array(data_X[0:int(n*0.7)])
    train_y = np.array(data_y[0:int(n*0.7)])

    val_X = np.array(data_X[int(n*0.7):int(n*0.9)])
    val_y = np.array(data_y[int(n*0.7):int(n*0.9)])

    test_X = np.array(data_X[int(n*0.9):])
    test_y = np.array(data_y[int(n*0.9):])

    validation_data = (val_X,val_y)
    
    
    model2 = Sequential()


    forward_layer = LSTM(64, return_sequences=True)
    backward_layer = LSTM(64, activation='relu', return_sequences=True,
                          go_backwards=True)

    model2.add(Bidirectional(forward_layer, backward_layer=backward_layer,
                            input_shape=(10, 4)))

    model2.add(Dropout(0.2))

    model2.add(Bidirectional(LSTM(64)))

    model2.add(Dropout(0.2))

    model2.add(Dense(units=1))


    model2.summary()

    model2.compile(optimizer='adam', 
                  loss='mean_squared_error')
    model2.fit(train_X, 
              train_y, 
              epochs=100, 
              batch_size=30,
              validation_data=validation_data
             )

    pred_y = model2.predict(test_X)
    
    
    RMSE_predict=np.sqrt(mean_squared_error(test_y, pred_y))
    f2_y_predict = r2_score(test_y, pred_y)
    
    return RMSE_predict,f2_y_predict

# %%
a,b,c=BLSTM('035420')
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_10 (Bidirecti  (None, 10, 128)          35328
#  onal)
#
#  dropout_10 (Dropout)        (None, 10, 128)           0
#
#  bidirectional_11 (Bidirecti  (None, 128)              98816
#  onal)
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 134,273
# Trainable params: 134,273
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 a,b,c=BLSTM('035420')
#
# Cell In[71], line 63, in BLSTM(finnum)
#      59 model2.summary()
#      61 model2.compile(optimizer='adam',
#      62               loss='mean_squared_error')
# ---> 63 model2.fit(train_X,
#      64           train_y,
#      65           epochs=100,
#      66           batch_size=30,
#      67           validation_data=validation_data
#      68          )
#      70 pred_y = model2.predict(test_X)
#      73 RMSE_predict=np.sqrt(mean_squared_error(test_y, pred_y))
#
# File ~\AppData\Local\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:980, in Function._call(self, *args, **kwds)
#     976     pass  # Fall through to cond-based initialization.
#     977   else:
#     978     # Lifting succeeded, so variables are initialized and we can run the
#     979     # stateless function.
# --> 980     return self._stateless_fn(*args, **kwds)
#     981 else:
#     982   _, _, filtered_flat_args = (
#     983       self._stateful_fn._function_spec.canonicalize_function_inputs(  # pylint: disable=protected-access
#     984           *args, **kwds))
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:2495, in Function.__call__(self, *args, **kwargs)
#    2492 """Calls a graph function specialized to the inputs."""
#    2493 with self._lock:
#    2494   (graph_function,
# -> 2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:2760, in Function._maybe_define_function(self, args, kwargs)
#    2758   # Only get placeholders for arguments, not captures
#    2759   args, kwargs = placeholder_dict["args"]
# -> 2760 graph_function = self._create_graph_function(args, kwargs)
#    2762 graph_capture_container = graph_function.graph._capture_func_lib  # pylint: disable=protected-access
#    2763 # Maintain the list of all captures
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:2670, in Function._create_graph_function(self, args, kwargs)
#    2665 missing_arg_names = [
#    2666     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    2667 ]
#    2668 arg_names = base_arg_names + missing_arg_names
#    2669 graph_function = ConcreteFunction(
# -> 2670     func_graph_module.func_graph_from_py_func(
#    2671         self._name,
#    2672         self._python_function,
#    2673         args,
#    2674         kwargs,
#    2675         self.input_signature,
#    2676         autograph=self._autograph,
#    2677         autograph_options=self._autograph_options,
#    2678         arg_names=arg_names,
#    2679         capture_by_value=self._capture_by_value),
#    2680     self._function_attributes,
#    2681     spec=self.function_spec,
#    2682     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    2683     # scope. This is not the default behavior since it gets used in some
#    2684     # places (like Keras) where the FuncGraph lives longer than the
#    2685     # ConcreteFunction.
#    2686     shared_func_graph=False)
#    2687 return graph_function
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py:1247, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1244 else:
#    1245   _, original_func = tf_decorator.unwrap(python_func)
# -> 1247 func_outputs = python_func(*func_args, **func_kwargs)
#    1249 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1250 # TensorArrays and `None`s.
#    1251 func_outputs = nest.map_structure(
#    1252     convert, func_outputs, expand_composites=True)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:677, in Function._defun_with_scope.<locals>.wrapped_fn(*args, **kwds)
#     673 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     674   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     675   # the function a weak reference to itself to avoid a reference cycle.
#     676   with OptionalXlaContext(compile_with_xla):
# --> 677     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     678   return out
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py:1222, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    1220 # TODO(mdan): Push this block higher in tf.function's call stack.
#    1221 try:
# -> 1222   return autograph.converted_call(
#    1223       original_func,
#    1224       args,
#    1225       kwargs,
#    1226       options=autograph.ConversionOptions(
#    1227           recursive=True,
#    1228           optional_features=autograph_options,
#    1229           user_requested=True,
#    1230       ))
#    1231 except Exception as e:  # pylint:disable=broad-except
#    1232   if hasattr(e, "ag_error_metadata"):
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\__autograph_generated_filesb1m3rf_.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     457 if kwargs is not None:
#     458   return f(*args, **kwargs)
# --> 459 return f(*args)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\keras\engine\training.py:1146, in Model.make_train_function.<locals>.step_function(model, iterator)
#    1142     run_step = tf.function(
#    1143         run_step, jit_compile=True, reduce_retracing=True
#    1144     )
#    1145 data = next(iterator)
# -> 1146 outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1147 outputs = reduce_per_replica(
#    1148     outputs, self.distribute_strategy, reduction="first"
#    1149 )
#    1150 return outputs
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1315, in StrategyBase.run(***failed resolving arguments***)
#    1310 with self.scope():
#    1311   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1312   # applied when the caller is also in Eager mode.
#    1313   fn = autograph.tf_convert(
#    1314       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1315   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2891, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    2889   kwargs = {}
#    2890 with self._container_strategy().scope():
# -> 2891   return self._call_for_each_replica(fn, args, kwargs)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3692, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    3690 def _call_for_each_replica(self, fn, args, kwargs):
#    3691   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3692     return fn(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py:689, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     687 try:
#     688   with conversion_ctx:
# --> 689     return converted_call(f, args, kwargs, options=options)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py:458, in _call_unconverted(f, args, kwargs, options, update_cache)
#     455   return f.__self__.call(args, kwargs)
#     457 if kwargs is not None:
# --> 458   return f(*args, **kwargs)
#     459 return f(*args)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\keras\engine\training.py:1135, in Model.make_train_function.<locals>.step_function.<locals>.run_step(data)
#    1134 def run_step(data):
# -> 1135     outputs = model.train_step(data)
#    1136     # Ensure counter is updated only if `train_step` succeeds.
#    1137     with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# File ~\AppData\Local\anaconda3\lib\site-packages\keras\engine\training.py:997, in Model.train_step(self, data)
#     995 self._validate_target_and_loss(y, loss)
#     996 # Run backwards pass.
# --> 997 self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     998 return self.compute_metrics(x, y, y_pred, sample_weight)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py:576, in OptimizerV2.minimize(self, loss, var_list, grad_loss, name, tape)
#     545 def minimize(self, loss, var_list, grad_loss=None, name=None, tape=None):
#     546     """Minimize `loss` by updating `var_list`.
#     547
#     548     This method simply computes gradient using `tf.GradientTape` and calls
#    (...)
#     574
#     575     """
# --> 576     grads_and_vars = self._compute_gradients(
#     577         loss, var_list=var_list, grad_loss=grad_loss, tape=tape
#     578     )
#     579     return self.apply_gradients(grads_and_vars, name=name)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py:634, in OptimizerV2._compute_gradients(self, loss, var_list, grad_loss, tape)
#     632 var_list = tf.nest.flatten(var_list)
#     633 with tf.name_scope(self._name + "/gradients"):
# --> 634     grads_and_vars = self._get_gradients(
#     635         tape, loss, var_list, grad_loss
#     636     )
#     638 self._assert_valid_dtypes(
#     639     [
#     640         v
#    (...)
#     643     ]
#     644 )
#     646 return grads_and_vars
#
# File ~\AppData\Local\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py:510, in OptimizerV2._get_gradients(self, tape, loss, var_list, grad_loss)
#     508 def _get_gradients(self, tape, loss, var_list, grad_loss=None):
#     509     """Called in `minimize` to compute gradients from loss."""
# --> 510     grads = tape.gradient(loss, var_list, grad_loss)
#     511     return list(zip(grads, var_list))
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\eager\backprop.py:1113, in GradientTape.gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1107   output_gradients = (
#    1108       composite_tensor_gradient.get_flat_tensors_for_gradients(
#    1109           output_gradients))
#    1110   output_gradients = [None if x is None else ops.convert_to_tensor(x)
#    1111                       for x in output_gradients]
# -> 1113 flat_grad = imperative_grad.imperative_grad(
#    1114     self._tape,
#    1115     flat_targets,
#    1116     flat_sources,
#    1117     output_gradients=output_gradients,
#    1118     sources_raw=flat_sources_raw,
#    1119     unconnected_gradients=unconnected_gradients)
#    1121 if not self._persistent:
#    1122   # Keep track of watched variables before setting tape to None
#    1123   self._watched_variables = self._tape.watched_variables()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\eager\imperative_grad.py:67, in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      63 except ValueError:
#      64   raise ValueError(
#      65       "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
# ---> 67 return pywrap_tfe.TFE_Py_TapeGradient(
#      68     tape._tape,  # pylint: disable=protected-access
#      69     target,
#      70     sources,
#      71     output_gradients,
#      72     sources_raw,
#      73     compat.as_str(unconnected_gradients.value))
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:752, in _DelayedRewriteGradientFunctions._backward.<locals>._backward_function(*args)
#     750 def _backward_function(*args):
#     751   call_op = outputs[0].op
# --> 752   return self._rewrite_forward_and_call_backward(call_op, *args)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:668, in _DelayedRewriteGradientFunctions._rewrite_forward_and_call_backward(self, op, *doutputs)
#     666 def _rewrite_forward_and_call_backward(self, op, *doutputs):
#     667   """Add outputs to the forward call and feed them to the grad function."""
# --> 668   forward_function, backwards_function = self.forward_backward(len(doutputs))
#     669   if not backwards_function.outputs:
#     670     return backwards_function.structured_outputs
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:601, in _DelayedRewriteGradientFunctions.forward_backward(self, num_doutputs)
#     599 if forward_backward is not None:
#     600   return forward_backward
# --> 601 forward, backward = self._construct_forward_backward(num_doutputs)
#     602 self._cached_function_pairs[num_doutputs] = (forward, backward)
#     603 return forward, backward
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:644, in _DelayedRewriteGradientFunctions._construct_forward_backward(self, num_doutputs)
#     641 with self._func_graph.as_default():
#     642   backwards_graph = func_graph_module.FuncGraph(
#     643       _backward_name(self._func_graph.name))
# --> 644   func_graph_module.func_graph_from_py_func(
#     645       name=backwards_graph.name,
#     646       python_func=_backprop_function,
#     647       args=[], kwargs={},
#     648       signature=signature,
#     649       func_graph=backwards_graph)
#     650   backwards_graph_captures = backwards_graph.external_captures
#     651   captures_from_forward = [
#     652       c for c in backwards_graph_captures if
#     653       not isinstance(c, ops.EagerTensor) and c.graph is self._func_graph]
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py:1247, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1244 else:
#    1245   _, original_func = tf_decorator.unwrap(python_func)
# -> 1247 func_outputs = python_func(*func_args, **func_kwargs)
#    1249 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1250 # TensorArrays and `None`s.
#    1251 func_outputs = nest.map_structure(
#    1252     convert, func_outputs, expand_composites=True)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:635, in _DelayedRewriteGradientFunctions._construct_forward_backward.<locals>._backprop_function(*grad_ys)
#     633 def _backprop_function(*grad_ys):
#     634   with ops.device(None):
# --> 635     return gradients_util._GradientsHelper(  # pylint: disable=protected-access
#     636         trainable_outputs,
#     637         self._func_graph.inputs,
#     638         grad_ys=grad_ys,
#     639         src_graph=self._func_graph)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\ops\gradients_util.py:695, in _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, unconnected_gradients, src_graph)
#     690 with src_graph._original_op(op):
#     691   # pylint: enable=protected-access
#     692   if grad_fn:
#     693     # If grad_fn was found, do not use SymbolicGradient even for
#     694     # functions.
# --> 695     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     696                              lambda: grad_fn(op, *out_grads))
#     697   else:
#     698     # For function call ops, we add a 'SymbolicGradient'
#     699     # node to the graph to compute gradients.
#     700     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     701                              lambda: _SymGrad(op, out_grads))
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\ops\gradients_util.py:329, in _MaybeCompile(scope, op, func, grad_fn)
#     326     xla_compile = False
#     328 if not xla_compile:
# --> 329   return grad_fn()  # Exit early
#     331 # If the gradients are supposed to be compiled separately, we give them a
#     332 # _XlaScope name that is based on the name_scope of the gradients.  Otherwise
#     333 # they just inherit the existing _XlaScope name, which lets them be merged
#     334 # together with the non-gradient computation.
#     335 if xla_separate_compiled_gradients:
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\ops\gradients_util.py:696, in _GradientsHelper.<locals>.<lambda>()
#     690 with src_graph._original_op(op):
#     691   # pylint: enable=protected-access
#     692   if grad_fn:
#     693     # If grad_fn was found, do not use SymbolicGradient even for
#     694     # functions.
#     695     in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 696                              lambda: grad_fn(op, *out_grads))
#     697   else:
#     698     # For function call ops, we add a 'SymbolicGradient'
#     699     # node to the graph to compute gradients.
#     700     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     701                              lambda: _SymGrad(op, out_grads))
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\ops\while_v2.py:464, in _WhileGrad(op, *grads)
#     453 outputs = _build_while_op(
#     454     loop_vars,
#     455     cond_grad_graph,
#    (...)
#     460     num_original_outputs=len(body_grad_graph.outputs),
#     461     stateful_parallelism=stateful_parallelism)
#     463 # See comment in while_loop.
# --> 464 outputs = [array_ops.identity(t) for t in outputs]
#     465 return _get_structured_grad_output(outputs, grads, body_grad_graph)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\ops\while_v2.py:464, in <listcomp>(.0)
#     453 outputs = _build_while_op(
#     454     loop_vars,
#     455     cond_grad_graph,
#    (...)
#     460     num_original_outputs=len(body_grad_graph.outputs),
#     461     stateful_parallelism=stateful_parallelism)
#     463 # See comment in while_loop.
# --> 464 outputs = [array_ops.identity(t) for t in outputs]
#     465 return _get_structured_grad_output(outputs, grads, body_grad_graph)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\ops\array_ops.py:294, in identity(input, name)
#     290 if context.executing_eagerly() and not hasattr(input, "graph"):
#     291   # Make sure we get an input with handle data attached from resource
#     292   # variables. Variables have correct handle data when graph building.
#     293   input = ops.convert_to_tensor(input)
# --> 294 ret = gen_array_ops.identity(input, name=name)
#     295 # Propagate handle data for happier shape inference for resource variables.
#     296 if hasattr(input, "_handle_data"):
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\ops\gen_array_ops.py:4081, in identity(input, name)
#    4079     pass  # Add nodes to the TensorFlow graph.
#    4080 # Add nodes to the TensorFlow graph.
# -> 4081 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    4082       "Identity", input=input, name=name)
#    4083 _result = _outputs[:]
#    4084 if _execute.must_record_gradient():
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:797, in _apply_op_helper(op_type_name, name, **keywords)
#     792 must_colocate_inputs = [val for arg, val in zip(op_def.input_arg, inputs)
#     793                         if arg.is_ref]
#     794 with _MaybeColocateWith(must_colocate_inputs):
#     795   # Add Op to graph
#     796   # pylint: disable=protected-access
# --> 797   op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     798                              name=scope, input_types=input_types,
#     799                              attrs=attr_protos, op_def=op_def)
#     801 # `outputs` is returned as a separate return value so that the output
#     802 # tensors can the `op` per se can be decoupled so that the
#     803 # `op_callbacks` can function properly. See framework/op_callbacks.py
#     804 # for more details.
#     805 outputs = op.outputs
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py:735, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     733   inp = self.capture(inp)
#     734   captured_inputs.append(inp)
# --> 735 return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     736     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     737     compute_device)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py:3800, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3797 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    3798 # Session.run call cannot occur between creating and mutating the op.
#    3799 with self._mutation_lock():
# -> 3800   ret = Operation(
#    3801       node_def,
#    3802       self,
#    3803       inputs=inputs,
#    3804       output_types=dtypes,
#    3805       control_inputs=control_inputs,
#    3806       input_types=input_types,
#    3807       original_op=self._default_original_op,
#    3808       op_def=op_def)
#    3809   self._create_op_helper(ret, compute_device=compute_device)
#    3810 return ret
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py:2108, in Operation.__init__(***failed resolving arguments***)
#    2105     control_input_ops.append(control_op)
#    2107 # Initialize c_op from node_def and other inputs
# -> 2108 c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    2109 self._init_from_c_op(c_op=c_op, g=g)
#    2111 self._original_op = original_op
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py:1966, in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1962   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    1963                                          serialized)
#    1965 try:
# -> 1966   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1967 except errors.InvalidArgumentError as e:
#    1968   # Convert to ValueError for backwards compatibility.
#    1969   raise ValueError(e.message)
#
# KeyboardInterrupt:

# %%
a
# Out:
# 0.0008701217593625188

# %%
b
# Out:
# 0.02949782633780208

# %%
c
# Out:
# 0.9113183897804472

# %%
kospi50 = pd.read_csv('./Kospi50.csv', encoding='cp949')

# %%
kospi50
# Out:
#       종목코드        종목명
# 0     5930       삼성전자
# 1   373220   LG에너지솔루션
# 2      660     SK하이닉스
# 3   207940   삼성바이오로직스
# 4     5490   POSCO홀딩스
# 5     6400      삼성SDI
# 6    51910       LG화학
# 7     5380        현대차
# 8    35420      NAVER
# 9     3670     포스코퓨처엠
# 10     270         기아
# 11   12330      현대모비스
# 12  105560       KB금융
# 13   68270       셀트리온
# 14   35720        카카오
# 15   28260       삼성물산
# 16   55550       신한지주
# 17   66570       LG전자
# 18   96770    SK이노베이션
# 19   32830       삼성생명
# 20    3550         LG
# 21     810       삼성화재
# 22   33780       KT&G
# 23  323410      카카오뱅크
# 24   15760       한국전력
# 25   86790     하나금융지주
# 26   18260    삼성에스디에스
# 27   34020    두산에너빌리티
# 28   34730         SK
# 29   10130       고려아연
# 30   17670      SK텔레콤
# 31    9150       삼성전기
# 32  352820        하이브
# 33  316140     우리금융지주
# 34   10950      S-Oil
# 35   24110       기업은행
# 36    9540   HD한국조선해양
# 37   30200         KT
# 38   11200        HMM
# 39   90430     아모레퍼시픽
# 40  259960       크래프톤
# 41   51900     LG생활건강
# 42  326030     SK바이오팜
# 43   86280     현대글로비스
# 44  377300      카카오페이
# 45   11170      롯데케미칼
# 46  302440  SK바이오사이언스
# 47   36570      엔씨소프트
# 48   34220    LG디스플레이
# 49  251270        넷마블

# %%
kospi50['종목코드']=kospi50['종목코드'].apply(lambda x : str(x).zfill(6))

# %%
kospi50['RMSE']=np.nan
kospi50['R2']=np.nan
kospi50
# Out:
#       종목코드        종목명  RMSE  R2
# 0   005930       삼성전자   NaN NaN
# 1   373220   LG에너지솔루션   NaN NaN
# 2   000660     SK하이닉스   NaN NaN
# 3   207940   삼성바이오로직스   NaN NaN
# 4   005490   POSCO홀딩스   NaN NaN
# 5   006400      삼성SDI   NaN NaN
# 6   051910       LG화학   NaN NaN
# 7   005380        현대차   NaN NaN
# 8   035420      NAVER   NaN NaN
# 9   003670     포스코퓨처엠   NaN NaN
# 10  000270         기아   NaN NaN
# 11  012330      현대모비스   NaN NaN
# 12  105560       KB금융   NaN NaN
# 13  068270       셀트리온   NaN NaN
# 14  035720        카카오   NaN NaN
# 15  028260       삼성물산   NaN NaN
# 16  055550       신한지주   NaN NaN
# 17  066570       LG전자   NaN NaN
# 18  096770    SK이노베이션   NaN NaN
# 19  032830       삼성생명   NaN NaN
# 20  003550         LG   NaN NaN
# 21  000810       삼성화재   NaN NaN
# 22  033780       KT&G   NaN NaN
# 23  323410      카카오뱅크   NaN NaN
# 24  015760       한국전력   NaN NaN
# 25  086790     하나금융지주   NaN NaN
# 26  018260    삼성에스디에스   NaN NaN
# 27  034020    두산에너빌리티   NaN NaN
# 28  034730         SK   NaN NaN
# 29  010130       고려아연   NaN NaN
# 30  017670      SK텔레콤   NaN NaN
# 31  009150       삼성전기   NaN NaN
# 32  352820        하이브   NaN NaN
# 33  316140     우리금융지주   NaN NaN
# 34  010950      S-Oil   NaN NaN
# 35  024110       기업은행   NaN NaN
# 36  009540   HD한국조선해양   NaN NaN
# 37  030200         KT   NaN NaN
# 38  011200        HMM   NaN NaN
# 39  090430     아모레퍼시픽   NaN NaN
# 40  259960       크래프톤   NaN NaN
# 41  051900     LG생활건강   NaN NaN
# 42  326030     SK바이오팜   NaN NaN
# 43  086280     현대글로비스   NaN NaN
# 44  377300      카카오페이   NaN NaN
# 45  011170      롯데케미칼   NaN NaN
# 46  302440  SK바이오사이언스   NaN NaN
# 47  036570      엔씨소프트   NaN NaN
# 48  034220    LG디스플레이   NaN NaN
# 49  251270        넷마블   NaN NaN

# %%
for i in range(0,50):
    RMSE,R2=BLSTM(kospi50.iloc[i,0])
    kospi50.iloc[i,2]=RMSE
    kospi50.iloc[i,3]=R2
    print(kospi50.iloc[i,1])
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_14 (Bidirecti  (None, 10, 128)          35328
#  onal)
#
#  dropout_14 (Dropout)        (None, 10, 128)           0
#
#  bidirectional_15 (Bidirecti  (None, 128)              98816
#  onal)
#
#  dropout_15 (Dropout)        (None, 128)               0
#
#  dense_7 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 134,273
# Trainable params: 134,273
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 29/29 [==============================] - 7s 61ms/step - loss: 0.0460 - val_loss: 0.0136
# Epoch 2/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0186 - val_loss: 0.0201
# Epoch 3/100
# 29/29 [==============================] - 1s 17ms/step - loss: 0.0055 - val_loss: 0.0028
# Epoch 4/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 5/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0042 - val_loss: 0.0015
# Epoch 6/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 7/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0031 - val_loss: 0.0014
# Epoch 8/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0028 - val_loss: 0.0018
# Epoch 9/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0031 - val_loss: 0.0025
# Epoch 10/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 11/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 12/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 13/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0023 - val_loss: 0.0029
# Epoch 14/100
# 29/29 [==============================] - 1s 17ms/step - loss: 0.0026 - val_loss: 0.0013
# Epoch 15/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 16/100
# 29/29 [==============================] - 1s 17ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 17/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 18/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 19/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 20/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 21/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0028 - val_loss: 0.0022
# Epoch 22/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 23/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 24/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 25/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 26/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 27/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0028 - val_loss: 0.0016
# Epoch 28/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 29/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 30/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 31/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 32/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 33/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 34/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 35/100
# 29/29 [==============================] - 1s 17ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 36/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 37/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 38/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 39/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 40/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 41/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 42/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 43/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 44/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 45/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 46/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 47/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 48/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 49/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 50/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 51/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 52/100
# 29/29 [==============================] - 1s 20ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 53/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 54/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 55/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 56/100
# 29/29 [==============================] - 1s 17ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 57/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 58/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0014 - val_loss: 0.0055
# Epoch 59/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0015 - val_loss: 0.0031
# Epoch 60/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 61/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 62/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 63/100
# 29/29 [==============================] - 1s 17ms/step - loss: 0.0012 - val_loss: 9.3225e-04
# Epoch 64/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 65/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 66/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0016 - val_loss: 0.0027
# Epoch 67/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 68/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0014 - val_loss: 9.8104e-04
# Epoch 69/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 70/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 71/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 72/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0013 - val_loss: 9.8586e-04
# Epoch 73/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 74/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0012 - val_loss: 0.0038
# Epoch 75/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 76/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 77/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 78/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 79/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 80/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 81/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 82/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0015 - val_loss: 9.8089e-04
# Epoch 83/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 84/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0012 - val_loss: 0.0029
# Epoch 85/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0012 - val_loss: 9.1478e-04
# Epoch 86/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0011 - val_loss: 0.0024
# Epoch 87/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0012 - val_loss: 9.3495e-04
# Epoch 88/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0035
# Epoch 89/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0014 - val_loss: 0.0050
# Epoch 90/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 91/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 92/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0012 - val_loss: 0.0024
# Epoch 93/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 94/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0010 - val_loss: 0.0021
# Epoch 95/100
# 29/29 [==============================] - 0s 15ms/step - loss: 9.6655e-04 - val_loss: 0.0015
# Epoch 96/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0011 - val_loss: 8.8826e-04
# Epoch 97/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 98/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 99/100
# 29/29 [==============================] - 0s 15ms/step - loss: 9.1398e-04 - val_loss: 0.0015
# Epoch 100/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0010 - val_loss: 0.0013
# 4/4 [==============================] - 1s 5ms/step
# 삼성전자
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_16 (Bidirecti  (None, 10, 128)          35328
#  onal)
#
#  dropout_16 (Dropout)        (None, 10, 128)           0
#
#  bidirectional_17 (Bidirecti  (None, 128)              98816
#  onal)
#
#  dropout_17 (Dropout)        (None, 128)               0
#
#  dense_8 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 134,273
# Trainable params: 134,273
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 6/6 [==============================] - 7s 266ms/step - loss: 0.0326 - val_loss: 0.0213
# Epoch 2/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0141 - val_loss: 0.0432
# Epoch 3/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0086 - val_loss: 0.0607
# Epoch 4/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0081 - val_loss: 0.0266
# Epoch 5/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0083 - val_loss: 0.0165
# Epoch 6/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0075 - val_loss: 0.0386
# Epoch 7/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0069 - val_loss: 0.0440
# Epoch 8/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0074 - val_loss: 0.0281
# Epoch 9/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0069 - val_loss: 0.0316
# Epoch 10/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0066 - val_loss: 0.0391
# Epoch 11/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0061 - val_loss: 0.0231
# Epoch 12/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0057 - val_loss: 0.0249
# Epoch 13/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0053 - val_loss: 0.0177
# Epoch 14/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0056 - val_loss: 0.0212
# Epoch 15/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0047 - val_loss: 0.0199
# Epoch 16/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0046 - val_loss: 0.0126
# Epoch 17/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0044 - val_loss: 0.0214
# Epoch 18/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0039 - val_loss: 0.0102
# Epoch 19/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0038 - val_loss: 0.0139
# Epoch 20/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0041 - val_loss: 0.0154
# Epoch 21/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0040 - val_loss: 0.0145
# Epoch 22/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0036 - val_loss: 0.0132
# Epoch 23/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0038 - val_loss: 0.0070
# Epoch 24/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0037 - val_loss: 0.0152
# Epoch 25/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0043 - val_loss: 0.0062
# Epoch 26/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0034 - val_loss: 0.0118
# Epoch 27/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0033 - val_loss: 0.0070
# Epoch 28/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0041 - val_loss: 0.0127
# Epoch 29/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0034 - val_loss: 0.0097
# Epoch 30/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0039 - val_loss: 0.0166
# Epoch 31/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0039 - val_loss: 0.0299
# Epoch 32/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0042 - val_loss: 0.0058
# Epoch 33/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0033 - val_loss: 0.0220
# Epoch 34/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0036 - val_loss: 0.0076
# Epoch 35/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0029 - val_loss: 0.0142
# Epoch 36/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0030 - val_loss: 0.0092
# Epoch 37/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0032 - val_loss: 0.0109
# Epoch 38/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0028 - val_loss: 0.0117
# Epoch 39/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0027 - val_loss: 0.0120
# Epoch 40/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0033 - val_loss: 0.0093
# Epoch 41/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0028 - val_loss: 0.0093
# Epoch 42/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0029 - val_loss: 0.0054
# Epoch 43/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0033 - val_loss: 0.0201
# Epoch 44/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0030 - val_loss: 0.0094
# Epoch 45/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0032 - val_loss: 0.0131
# Epoch 46/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0031 - val_loss: 0.0121
# Epoch 47/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0030 - val_loss: 0.0145
# Epoch 48/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0028 - val_loss: 0.0185
# Epoch 49/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0024 - val_loss: 0.0054
# Epoch 50/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0033 - val_loss: 0.0315
# Epoch 51/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0049 - val_loss: 0.0055
# Epoch 52/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0043 - val_loss: 0.0232
# Epoch 53/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0037 - val_loss: 0.0053
# Epoch 54/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0026 - val_loss: 0.0213
# Epoch 55/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0042 - val_loss: 0.0058
# Epoch 56/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0031 - val_loss: 0.0132
# Epoch 57/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0032 - val_loss: 0.0062
# Epoch 58/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0034 - val_loss: 0.0150
# Epoch 59/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0030 - val_loss: 0.0133
# Epoch 60/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0026 - val_loss: 0.0078
# Epoch 61/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0024 - val_loss: 0.0114
# Epoch 62/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0024 - val_loss: 0.0071
# Epoch 63/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0026 - val_loss: 0.0162
# Epoch 64/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0026 - val_loss: 0.0068
# Epoch 65/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0027 - val_loss: 0.0154
# Epoch 66/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0024 - val_loss: 0.0067
# Epoch 67/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0028 - val_loss: 0.0227
# Epoch 68/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0042 - val_loss: 0.0049
# Epoch 69/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0058 - val_loss: 0.0203
# Epoch 70/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0044 - val_loss: 0.0086
# Epoch 71/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0033 - val_loss: 0.0124
# Epoch 72/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0029 - val_loss: 0.0166
# Epoch 73/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0029 - val_loss: 0.0110
# Epoch 74/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0026 - val_loss: 0.0217
# Epoch 75/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0025 - val_loss: 0.0199
# Epoch 76/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0023 - val_loss: 0.0198
# Epoch 77/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0027 - val_loss: 0.0144
# Epoch 78/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0023 - val_loss: 0.0115
# Epoch 79/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0027 - val_loss: 0.0108
# Epoch 80/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0023 - val_loss: 0.0132
# Epoch 81/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0027 - val_loss: 0.0096
# Epoch 82/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0023 - val_loss: 0.0076
# Epoch 83/100
# 6/6 [==============================] - 0s 27ms/step - loss: 0.0022 - val_loss: 0.0140
# Epoch 84/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0028 - val_loss: 0.0237
# Epoch 85/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0028 - val_loss: 0.0151
# Epoch 86/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0024 - val_loss: 0.0109
# Epoch 87/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0028 - val_loss: 0.0111
# Epoch 88/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0023 - val_loss: 0.0127
# Epoch 89/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0028 - val_loss: 0.0157
# Epoch 90/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0024 - val_loss: 0.0087
# Epoch 91/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0021 - val_loss: 0.0111
# Epoch 92/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0024 - val_loss: 0.0095
# Epoch 93/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0021 - val_loss: 0.0119
# Epoch 94/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0020 - val_loss: 0.0098
# Epoch 95/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0024 - val_loss: 0.0051
# Epoch 96/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0024 - val_loss: 0.0116
# Epoch 97/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0020 - val_loss: 0.0086
# Epoch 98/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0021 - val_loss: 0.0110
# Epoch 99/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0024 - val_loss: 0.0089
# Epoch 100/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0021 - val_loss: 0.0102
# 1/1 [==============================] - 1s 1s/step
# LG에너지솔루션
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_18 (Bidirecti  (None, 10, 128)          35328
#  onal)
#
#  dropout_18 (Dropout)        (None, 10, 128)           0
#
#  bidirectional_19 (Bidirecti  (None, 128)              98816
#  onal)
#
#  dropout_19 (Dropout)        (None, 128)               0
#
#  dense_9 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 134,273
# Trainable params: 134,273
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 29/29 [==============================] - 8s 55ms/step - loss: 0.0288 - val_loss: 0.0026
# Epoch 2/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0038 - val_loss: 0.0036
# Epoch 3/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0029 - val_loss: 0.0025
# Epoch 4/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 5/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0033 - val_loss: 0.0026
# Epoch 6/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 7/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0030 - val_loss: 0.0022
# Epoch 8/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 9/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 10/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 11/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 12/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0023 - val_loss: 0.0018
# Epoch 13/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 14/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 15/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0027
# Epoch 16/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 17/100
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 18/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 19/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 20/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 21/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 22/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 23/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 24/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 25/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 26/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 27/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 28/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 29/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 30/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 31/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 32/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 33/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 34/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0016 - val_loss: 0.0035
# Epoch 35/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 36/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 37/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 38/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 39/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 40/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 41/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 42/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 43/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 44/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 45/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 46/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0014 - val_loss: 0.0025
# Epoch 47/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0015 - val_loss: 0.0029
# Epoch 48/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 49/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 50/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0017 - val_loss: 0.0032
# Epoch 51/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 52/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 53/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0014 - val_loss: 0.0061
# Epoch 54/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 55/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 56/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0012 - val_loss: 0.0024
# Epoch 57/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 58/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 59/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 60/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 61/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0013 - val_loss: 0.0032
# Epoch 62/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 63/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 64/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 65/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 66/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 67/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 68/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 69/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0014 - val_loss: 0.0037
# Epoch 70/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 71/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 72/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 73/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 74/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 75/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0012 - val_loss: 0.0022
# Epoch 76/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 77/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 78/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 79/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 80/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 81/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0030
# Epoch 82/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 83/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 84/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 85/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 86/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 87/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0014 - val_loss: 0.0030
# Epoch 88/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 89/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 90/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 91/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 92/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 93/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0036
# Epoch 94/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 95/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 96/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 97/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0011 - val_loss: 0.0023
# Epoch 98/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0010 - val_loss: 0.0020
# Epoch 99/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 100/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0011 - val_loss: 0.0011
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002A0BF1CBE20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 [==============================] - 1s 6ms/step
# SK하이닉스
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_20 (Bidirecti  (None, 10, 128)          35328
#  onal)
#
#  dropout_20 (Dropout)        (None, 10, 128)           0
#
#  bidirectional_21 (Bidirecti  (None, 128)              98816
#  onal)
#
#  dropout_21 (Dropout)        (None, 128)               0
#
#  dense_10 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 134,273
# Trainable params: 134,273
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 29/29 [==============================] - 7s 57ms/step - loss: 0.0343 - val_loss: 0.0032
# Epoch 2/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0093 - val_loss: 0.0016
# Epoch 3/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0039 - val_loss: 0.0041
# Epoch 4/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0035 - val_loss: 0.0029
# Epoch 5/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0033 - val_loss: 0.0017
# Epoch 6/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 7/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0031 - val_loss: 0.0016
# Epoch 8/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0029 - val_loss: 0.0017
# Epoch 9/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 10/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 11/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 12/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 13/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 14/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 15/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0022 - val_loss: 0.0015
# Epoch 16/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 17/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 18/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0020 - val_loss: 0.0026
# Epoch 19/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 20/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 21/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 22/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 23/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 24/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 25/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 26/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 27/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 28/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 29/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 30/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 31/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 32/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 33/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 34/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 35/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0018 - val_loss: 0.0010
# Epoch 36/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 37/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0017 - val_loss: 0.0032
# Epoch 38/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 39/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 40/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 41/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 42/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 43/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 44/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 45/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 46/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 47/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 48/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 49/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 50/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 51/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 52/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0014 - val_loss: 0.0028
# Epoch 53/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 54/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 55/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 56/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 57/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0013 - val_loss: 9.7549e-04
# Epoch 58/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 59/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 60/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 61/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 62/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 63/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 64/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 65/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 66/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 67/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0052
# Epoch 68/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0017 - val_loss: 0.0041
# Epoch 69/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0033
# Epoch 70/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 71/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 72/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0010 - val_loss: 0.0020
# Epoch 73/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 74/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 75/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0014 - val_loss: 0.0059
# Epoch 76/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0014 - val_loss: 0.0038
# Epoch 77/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.0013 - val_loss: 0.0058
# Epoch 78/100
# 29/29 [==============================] - 1s 22ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 79/100
# 29/29 [==============================] - 1s 23ms/step - loss: 0.0014 - val_loss: 0.0028
# Epoch 80/100
# 29/29 [==============================] - 1s 17ms/step - loss: 0.0012 - val_loss: 0.0022
# Epoch 81/100
# 29/29 [==============================] - 1s 23ms/step - loss: 0.0012 - val_loss: 0.0028
# Epoch 82/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.0012 - val_loss: 0.0049
# Epoch 83/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.0013 - val_loss: 0.0057
# Epoch 84/100
# 29/29 [==============================] - 1s 20ms/step - loss: 0.0013 - val_loss: 0.0029
# Epoch 85/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 86/100
# 29/29 [==============================] - 1s 22ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 87/100
# 29/29 [==============================] - 1s 22ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 88/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 89/100
# 29/29 [==============================] - 1s 23ms/step - loss: 0.0010 - val_loss: 0.0023
# Epoch 90/100
# 29/29 [==============================] - 1s 20ms/step - loss: 0.0011 - val_loss: 0.0035
# Epoch 91/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0011 - val_loss: 0.0026
# Epoch 92/100
# 29/29 [==============================] - 1s 23ms/step - loss: 0.0013 - val_loss: 0.0025
# Epoch 93/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 94/100
# 29/29 [==============================] - 1s 23ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 95/100
# 29/29 [==============================] - 1s 21ms/step - loss: 9.6841e-04 - val_loss: 0.0013
# Epoch 96/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.0010 - val_loss: 0.0018
# Epoch 97/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 98/100
# 29/29 [==============================] - 1s 22ms/step - loss: 9.6615e-04 - val_loss: 0.0017
# Epoch 99/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.0010 - val_loss: 0.0021
# Epoch 100/100
# 29/29 [==============================] - 1s 27ms/step - loss: 9.1134e-04 - val_loss: 0.0014
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002A0C9C2BC70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 [==============================] - 1s 9ms/step
# 삼성바이오로직스
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_22 (Bidirecti  (None, 10, 128)          35328
#  onal)
#
#  dropout_22 (Dropout)        (None, 10, 128)           0
#
#  bidirectional_23 (Bidirecti  (None, 128)              98816
#  onal)
#
#  dropout_23 (Dropout)        (None, 128)               0
#
#  dense_11 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 134,273
# Trainable params: 134,273
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# ...
# Epoch 86/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0034 - val_loss: 0.0029
# Epoch 87/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0033 - val_loss: 0.0029
# Epoch 88/100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0032 - val_loss: 0.0028
# Epoch 89/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0030 - val_loss: 0.0025
# Epoch 90/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 91/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 92/100
# 7/7 [==============================] - 0s 44ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 93/100
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 94/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 95/100
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 96/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0023 - val_loss: 0.0028
# Epoch 97/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 98/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0025 - val_loss: 0.0030
# Epoch 99/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0020 - val_loss: 0.0029
# Epoch 100/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0027 - val_loss: 0.0031
# 1/1 [==============================] - 1s 1s/step
# 카카오페이
# Model: "sequential_52"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_104 (Bidirect  (None, 10, 128)          35328
#  ional)
#
#  dropout_104 (Dropout)       (None, 10, 128)           0
#
#  bidirectional_105 (Bidirect  (None, 128)              98816
#  ional)
#
#  dropout_105 (Dropout)       (None, 128)               0
#
#  dense_52 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 134,273
# Trainable params: 134,273
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 29/29 [==============================] - 9s 70ms/step - loss: 0.0216 - val_loss: 0.0031
# Epoch 2/100
# 29/29 [==============================] - 1s 20ms/step - loss: 0.0030 - val_loss: 6.4777e-04
# Epoch 3/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0024 - val_loss: 6.2634e-04
# Epoch 4/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0022 - val_loss: 7.2538e-04
# Epoch 5/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0021 - val_loss: 6.4323e-04
# Epoch 6/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0025 - val_loss: 5.8015e-04
# Epoch 7/100
# 29/29 [==============================] - 1s 20ms/step - loss: 0.0020 - val_loss: 5.7855e-04
# Epoch 8/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0021 - val_loss: 5.4632e-04
# Epoch 9/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0020 - val_loss: 6.9753e-04
# Epoch 10/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0020 - val_loss: 7.2624e-04
# Epoch 11/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0020 - val_loss: 6.0728e-04
# Epoch 12/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0017 - val_loss: 4.9643e-04
# Epoch 13/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.0018 - val_loss: 4.9619e-04
# Epoch 14/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.0018 - val_loss: 5.4513e-04
# Epoch 15/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.0017 - val_loss: 4.5083e-04
# Epoch 16/100
# 29/29 [==============================] - 1s 23ms/step - loss: 0.0017 - val_loss: 4.4933e-04
# Epoch 17/100
# 29/29 [==============================] - 1s 23ms/step - loss: 0.0019 - val_loss: 5.1852e-04
# Epoch 18/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0019 - val_loss: 4.2349e-04
# Epoch 19/100
# 29/29 [==============================] - 1s 22ms/step - loss: 0.0014 - val_loss: 4.8440e-04
# Epoch 20/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.0016 - val_loss: 5.4955e-04
# Epoch 21/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.0019 - val_loss: 7.2439e-04
# Epoch 22/100
# 29/29 [==============================] - 1s 22ms/step - loss: 0.0016 - val_loss: 6.7140e-04
# Epoch 23/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.0015 - val_loss: 4.7826e-04
# Epoch 24/100
# 29/29 [==============================] - 1s 22ms/step - loss: 0.0014 - val_loss: 4.1973e-04
# Epoch 25/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.0016 - val_loss: 4.6794e-04
# Epoch 26/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0014 - val_loss: 6.3534e-04
# Epoch 27/100
# 29/29 [==============================] - 1s 20ms/step - loss: 0.0014 - val_loss: 8.8444e-04
# Epoch 28/100
# 29/29 [==============================] - 1s 20ms/step - loss: 0.0017 - val_loss: 5.9879e-04
# Epoch 29/100
# 29/29 [==============================] - 1s 20ms/step - loss: 0.0014 - val_loss: 4.1405e-04
# Epoch 30/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0016 - val_loss: 4.3512e-04
# Epoch 31/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0015 - val_loss: 4.2432e-04
# Epoch 32/100
# 29/29 [==============================] - 1s 23ms/step - loss: 0.0015 - val_loss: 5.5796e-04
# Epoch 33/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.0015 - val_loss: 4.4681e-04
# Epoch 34/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.0014 - val_loss: 4.3936e-04
# Epoch 35/100
# 29/29 [==============================] - 1s 20ms/step - loss: 0.0015 - val_loss: 4.7175e-04
# Epoch 36/100
# 29/29 [==============================] - 1s 20ms/step - loss: 0.0014 - val_loss: 3.8964e-04
# Epoch 37/100
# 29/29 [==============================] - 1s 20ms/step - loss: 0.0015 - val_loss: 3.8352e-04
# Epoch 38/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.0013 - val_loss: 3.6045e-04
# Epoch 39/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0014 - val_loss: 3.4066e-04
# Epoch 40/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.0013 - val_loss: 5.2408e-04
# Epoch 41/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.0014 - val_loss: 4.0120e-04
# Epoch 42/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.0013 - val_loss: 3.6035e-04
# Epoch 43/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.0012 - val_loss: 4.4668e-04
# Epoch 44/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.0014 - val_loss: 4.1802e-04
# Epoch 45/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.0013 - val_loss: 3.4814e-04
# Epoch 46/100
# 29/29 [==============================] - 1s 23ms/step - loss: 0.0012 - val_loss: 3.2127e-04
# Epoch 47/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0012 - val_loss: 3.6751e-04
# Epoch 48/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0012 - val_loss: 3.2003e-04
# Epoch 49/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0012 - val_loss: 3.0360e-04
# Epoch 50/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0012 - val_loss: 3.2824e-04
# Epoch 51/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0012 - val_loss: 3.4238e-04
# Epoch 52/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0014 - val_loss: 5.6811e-04
# Epoch 53/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 4.1395e-04
# Epoch 54/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0012 - val_loss: 3.1433e-04
# Epoch 55/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0012 - val_loss: 3.8232e-04
# Epoch 56/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0013 - val_loss: 3.7055e-04
# Epoch 57/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0010 - val_loss: 2.9635e-04
# Epoch 58/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 3.5286e-04
# Epoch 59/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0012 - val_loss: 2.8586e-04
# Epoch 60/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0012 - val_loss: 2.8298e-04
# Epoch 61/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0012 - val_loss: 3.6393e-04
# Epoch 62/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0012 - val_loss: 2.9931e-04
# Epoch 63/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0012 - val_loss: 4.4590e-04
# Epoch 64/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0011 - val_loss: 2.9711e-04
# Epoch 65/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0011 - val_loss: 2.8526e-04
# Epoch 66/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0010 - val_loss: 2.9826e-04
# Epoch 67/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.0011 - val_loss: 3.0930e-04
# Epoch 68/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0014 - val_loss: 4.2010e-04
# Epoch 69/100
# 29/29 [==============================] - 1s 22ms/step - loss: 0.0016 - val_loss: 3.4866e-04
# Epoch 70/100
# 29/29 [==============================] - 1s 22ms/step - loss: 0.0010 - val_loss: 3.0275e-04
# Epoch 71/100
# 29/29 [==============================] - 1s 46ms/step - loss: 9.6584e-04 - val_loss: 2.8198e-04
# Epoch 72/100
# 29/29 [==============================] - 1s 41ms/step - loss: 9.4097e-04 - val_loss: 2.8122e-04
# Epoch 73/100
# 29/29 [==============================] - 1s 22ms/step - loss: 0.0011 - val_loss: 3.3968e-04
# Epoch 74/100
# 29/29 [==============================] - 1s 22ms/step - loss: 0.0011 - val_loss: 2.6332e-04
# Epoch 75/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0010 - val_loss: 2.6836e-04
# Epoch 76/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0012 - val_loss: 3.5085e-04
# Epoch 77/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 2.9549e-04
# Epoch 78/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0010 - val_loss: 3.8991e-04
# Epoch 79/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0012 - val_loss: 2.7590e-04
# Epoch 80/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.0010 - val_loss: 2.7300e-04
# Epoch 81/100
# 29/29 [==============================] - 1s 18ms/step - loss: 9.2102e-04 - val_loss: 2.9563e-04
# Epoch 82/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.0011 - val_loss: 3.6299e-04
# Epoch 83/100
# 29/29 [==============================] - 1s 23ms/step - loss: 0.0012 - val_loss: 3.4740e-04
# Epoch 84/100
# 29/29 [==============================] - 1s 27ms/step - loss: 9.6772e-04 - val_loss: 2.6259e-04
# Epoch 85/100
# 29/29 [==============================] - 1s 25ms/step - loss: 9.9628e-04 - val_loss: 2.6279e-04
# Epoch 86/100
# 29/29 [==============================] - 1s 23ms/step - loss: 0.0010 - val_loss: 4.2381e-04
# Epoch 87/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.0013 - val_loss: 2.6851e-04
# Epoch 88/100
# 29/29 [==============================] - 1s 22ms/step - loss: 9.6785e-04 - val_loss: 2.7929e-04
# Epoch 89/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.0010 - val_loss: 4.6048e-04
# Epoch 90/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.0010 - val_loss: 2.9856e-04
# Epoch 91/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.0010 - val_loss: 2.5461e-04
# Epoch 92/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.0011 - val_loss: 3.0903e-04
# Epoch 93/100
# 29/29 [==============================] - 1s 22ms/step - loss: 0.0010 - val_loss: 3.1190e-04
# Epoch 94/100
# 29/29 [==============================] - 1s 45ms/step - loss: 9.2769e-04 - val_loss: 3.0035e-04
# Epoch 95/100
# 29/29 [==============================] - 1s 24ms/step - loss: 9.2740e-04 - val_loss: 2.8274e-04
# Epoch 96/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 2.5129e-04
# Epoch 97/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 2.8080e-04
# Epoch 98/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.0010 - val_loss: 2.5969e-04
# Epoch 99/100
# 29/29 [==============================] - 1s 22ms/step - loss: 9.8024e-04 - val_loss: 3.7618e-04
# Epoch 100/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.0011 - val_loss: 3.2641e-04
# 4/4 [==============================] - 1s 7ms/step
# 롯데케미칼
# Model: "sequential_53"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_106 (Bidirect  (None, 10, 128)          35328
#  ional)
#
#  dropout_106 (Dropout)       (None, 10, 128)           0
#
#  bidirectional_107 (Bidirect  (None, 128)              98816
#  ional)
#
#  dropout_107 (Dropout)       (None, 128)               0
#
#  dense_53 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 134,273
# Trainable params: 134,273
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 11/11 [==============================] - 8s 143ms/step - loss: 0.0928 - val_loss: 0.0148
# Epoch 2/100
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0139 - val_loss: 0.0026
# Epoch 3/100
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0085 - val_loss: 0.0086
# Epoch 4/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0084 - val_loss: 0.0026
# Epoch 5/100
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0064 - val_loss: 0.0041
# Epoch 6/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0053 - val_loss: 0.0022
# Epoch 7/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0049 - val_loss: 0.0021
# Epoch 8/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0051 - val_loss: 0.0021
# Epoch 9/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0054 - val_loss: 0.0018
# Epoch 10/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0044 - val_loss: 0.0014
# Epoch 11/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0037 - val_loss: 0.0021
# Epoch 12/100
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0044 - val_loss: 0.0017
# Epoch 13/100
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0045 - val_loss: 0.0020
# Epoch 14/100
#  1/11 [=>............................] - ETA: 0s - loss: 0.0043

# %%
import pickle

with open( "./kospi50BLSTM", "wb" ) as file:
    pickle.dump( kospi50, file)
